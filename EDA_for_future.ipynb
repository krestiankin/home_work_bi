# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %matplotlib inline

# %%
diamonds = sns.load_dataset("diamonds")

# %%
diamonds.head(10)
# Out:
#    carat        cut color clarity  depth  table  price     x     y     z
# 0   0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 5   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 6   0.24  Very Good     I    VVS1   62.3   57.0    336  3.95  3.98  2.47
# 7   0.26  Very Good     H     SI1   61.9   55.0    337  4.07  4.11  2.53
# 8   0.22       Fair     E     VS2   65.1   61.0    337  3.87  3.78  2.49
# 9   0.23  Very Good     H     VS1   59.4   61.0    338  4.00  4.05  2.39

# %%
diamonds.tail(10)
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 53930   0.71    Premium     E     SI1   60.5   55.0   2756  5.79  5.74  3.49
# 53931   0.71    Premium     F     SI1   59.8   62.0   2756  5.74  5.73  3.43
# 53932   0.70  Very Good     E     VS2   60.5   59.0   2757  5.71  5.76  3.47
# 53933   0.70  Very Good     E     VS2   61.2   59.0   2757  5.69  5.72  3.49
# 53934   0.72    Premium     D     SI1   62.7   59.0   2757  5.69  5.73  3.58
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64

# %%
diamonds.columns
# Out:
# Index(['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'price', 'x', 'y',
#        'z'],
#       dtype='object')

# %%
diamonds.info()
# diamonds.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  category
#  2   color    53940 non-null  category
#  3   clarity  53940 non-null  category
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: category(3), float64(6), int64(1)
# memory usage: 3.0 MB

# %%
diamonds.describe().T
# Out:
#          count         mean          std    min     25%      50%      75%
# carat  53940.0     0.797940     0.474011    0.2    0.40     0.70     1.04  \
# depth  53940.0    61.749405     1.432621   43.0   61.00    61.80    62.50
# table  53940.0    57.457184     2.234491   43.0   56.00    57.00    59.00
# price  53940.0  3932.799722  3989.439738  326.0  950.00  2401.00  5324.25
# x      53940.0     5.731157     1.121761    0.0    4.71     5.70     6.54
# y      53940.0     5.734526     1.142135    0.0    4.72     5.71     6.54
# z      53940.0     3.538734     0.705699    0.0    2.91     3.53     4.04
#
#             max
# carat      5.01
# depth     79.00
# table     95.00
# price  18823.00
# x         10.74
# y         58.90
# z         31.80

# %%
# diamonds.nunique(axis=0, dropna=True)
# diamonds.isnull().sum()
# diamonds.isna().sum()
# diamonds.duplicated().sum()
# diamonds.value_counts(normalize=False, dropna=False)
# diamonds.dropna()
# diamonds.drop_duplicates(inplace=False)
# diamonds.memory_usage()
diamonds.select_dtypes(include=['category'])
# Out:
#              cut color clarity
# 0          Ideal     E     SI2
# 1        Premium     E     SI1
# 2           Good     E     VS1
# 3        Premium     I     VS2
# 4           Good     J     SI2
# ...          ...   ...     ...
# 53935      Ideal     D     SI1
# 53936       Good     D     SI1
# 53937  Very Good     D     SI1
# 53938    Premium     H     SI2
# 53939      Ideal     D     SI2
#
# [53940 rows x 3 columns]

# %%
# розрахунок Nan в % до всього DF та впорядкування
diamonds_nan = diamonds.isna().sum() * 100 / len(diamonds)
diamonds_nan[diamonds_nan > 0].sort_values()
# Out:
# Series([], dtype: float64)

# %%
plt.figure(figsize=(5, 3), dpi=200)
sns.barplot(x=diamonds_nan.index, y=diamonds_nan)
plt.xticks(rotation=60)
plt.ylim(0, 1);

# %%
sns.heatmap(diamonds.isna().T);

# %%
#reg
sns.regplot(data=diamonds, x='carat', y='price');

# %%
x = np.random.normal(0, 1, 50)
y = x * 2 + np.random.normal(0, 2, size=x.size)
sns.regplot(x=x, y=y);
# Out:
# <Axes: >

# %%
sns.heatmap(diamonds.corr(), annot= True, cmap = 'inferno');

# %%
titanic = sns.load_dataset("titanic")

# %%
g = sns.catplot(
    data=titanic,
    x="fare", y="embark_town", row="class",
    kind="box", orient="h",
    sharex=False, margin_titles=True,
    height=1.5, aspect=4,
)
g.set(xlabel="Fare", ylabel="")
g.set_titles(row_template="{row_name} class")
for ax in g.axes.flat:
    ax.xaxis.set_major_formatter('${x:.0f}')

# %%
# sns.jointplot(data=titanic);

# %%
import seaborn.objects as so

# %%
(
    so.Plot(titanic, x="age", y="survived", color="sex")
    .add(so.Dots())
    .facet(row="pclass")
    .add(so.Line(), so.PolyFit())
)

# %%
tips = sns.load_dataset("tips")

# %%
#3 var
sns.lmplot(x="total_bill", y="tip", hue="smoker", data=tips);

# %% [markdown]
# > 4. Який взаємозв'язок між:
# >>a. Віком та виживанням?
# >>b. Статтю та виживанням?
# >>c. Клас і виживання?

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class
# 0         0       3    male  22.0      1      0   7.2500        S  Third  \
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
#4 var facets (col=)

sns.lmplot(data=titanic, x="age", y="survived", hue="sex")#, col="pclass");

# %%
# 5 variadle
sns.lmplot(x="total_bill", y="tip", hue="smoker", col="time", row="sex", data=tips, height=3);

# %%
# Введіть кількість рядків для ялинки
n = int(input("Введіть кількість рядків для ялинки: "))

# Виведення ялинки
for i in range(1, n+1):
    print(" "*(n-i) + "* "*(i))
# Out:
#          *
#         * *
#        * * *
#       * * * *
#      * * * * *
#     * * * * * *
#    * * * * * * *
#   * * * * * * * *
#  * * * * * * * * *
# * * * * * * * * * *
