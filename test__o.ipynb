# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
fig, ax = plt.subplots()
ax.plot([1, 2, 3, 4], [6, 7, 8, 9]),
ax.legend()
iris = sns.load_dataset('iris')
iris.head()
iris.info()
iris.describe()
iris.isnull().sum()
iris.duplicated().sum()
sns.get_dataset_names()
plt.figure(figsize = (6,4)) # встановити розмір графіку

# %%
sns.countplot(x= iris.species, data = iris); # показати кіл-к данних

plt.xlabel('Class of iris') # встановити назву по осі x
plt.ylabel('Count') # встановити назву по осі y
plt.title('Iris spes') # встановити назву графіку
plt.show() # показати графік

# %%
#  data = iris, hue = забарвлення точок від категор данних, diag_kind - тип графіка
sns.pairplot(iris, hue='species', diag_kind='hist');

# %%
plt.subplots(figsize = (8,6))
sns.boxplot(data = iris, x = 'species', y = 'sepal_length');

# %%
iris.corr()

# %%
sns.heatmap(iris.corr());

# %%
sns.heatmap(iris.corr(), annot=True, cmap='coolwarm');

# %%
tips = sns.load_dataset('tips')
tips.head()

# %%
sns.boxplot(data = tips, x = 'day', y = 'tip', hue = 'smoker')
plt.show()

# %%
sns.violinplot(data= iris, x = 'species', y = 'petal_length');

# %%
sns.scatterplot(x = 'total_bill', y = 'tip', data = tips);
#plt.grid()

# %%
sns.jointplot(data=tips, x='total_bill', y='tip', kind = 'hex');

# %%
sns.jointplot(data=tips, x='total_bill', y='tip', kind="kde")

# %%
sns.jointplot(data=tips, x='total_bill', y='tip')

# %% [markdown]
# > 1. Load the “diamonds” dataset from seaborn.
# > 2. Show the countplot of the ‘cut’ field.
# > 3. Show the distplot of the ‘price’ field.
# > 4. Show the boxplot of the price based on cut. Do the
# results make sense?
# > 5. Show the violin plot of the size (in carat) based on
# cut. What information does this add to ex. 4?
# > 6. Show the same plot as ex. 5, this time split by
# diamond color.

# %%
d = sns.load_dataset('diamonds')
d.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
sns.countplot(data=d, x='cut', palette='bright') #bright, magma
# Out:
# <Axes: xlabel='cut', ylabel='count'>

# %%
sns.displot(data=d, x='price', palette='magma');
# Out:
# /tmp/ipykernel_3239139/3378867811.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.displot(data=d, x='price', palette='magma');

# %%
sns.boxplot(data=d, x='price', y='cut', palette='magma' )
# Out:
# <Axes: xlabel='price', ylabel='cut'>

# %%
sns.violinplot(data=d, x='carat', y='cut', palette='husl' )
# Out:
# <Axes: xlabel='carat', ylabel='cut'>

# %%
# %matplotlib widget
sns.violinplot(data=d, x='cut', y='carat', hue='color', palette='husl' )
# Out:
# <Axes: xlabel='cut', ylabel='carat'>
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Slide 17
# > 1. Use the same diamonds dataset; filter the dataset
# only to diamonds of size up to 0.6 carat and price up
# to $2000.
# > 2. Show a joint plot between size and price.
# > 3. Load the “tips” dataset. Show a pairplot of the
# dataset.
# > 4. Add a new column for whether the meal was on a
# weekend or weekday.
# > 5. Show a pairplot of the dataset split by weekday /
# weekend.

# %%
df17_1 = d.loc[(d['carat']<0.6)&(d['price']<2000)]
df17_1
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53635   0.30      Ideal     I    VVS1   62.1   56.0    552  4.30  4.33  2.68
# 53636   0.30      Ideal     D     SI1   61.6   57.0    552  4.28  4.32  2.65
# 53637   0.30  Very Good     D     SI1   62.5   57.0    552  4.26  4.28  2.67
# 53638   0.30      Ideal     D     SI1   61.0   57.0    552  4.29  4.33  2.63
# 53639   0.30      Ideal     D     SI1   61.0   56.0    552  4.35  4.37  2.66
#
# [23141 rows x 10 columns]

# %%
sns.jointplot(data=df17_1, x='carat', y='price', kind = 'hex');

# %%
# Load the “tips” dataset. Show a pairplot of the dataset.

df17_3 = sns.load_dataset('tips')

# %%
# %matplotlib inline
sns.pairplot(data=df17_3)

# %% [markdown]
# Add a new column for whether the meal was on a
# weekend or weekday.
# > 5. Show a pairplot of the dataset split by weekday /
# weekend.

# %%
df17_3.head(20)
# Out:
#     total_bill   tip     sex smoker  day    time  size
# 0        16.99  1.01  Female     No  Sun  Dinner     2
# 1        10.34  1.66    Male     No  Sun  Dinner     3
# 2        21.01  3.50    Male     No  Sun  Dinner     3
# 3        23.68  3.31    Male     No  Sun  Dinner     2
# 4        24.59  3.61  Female     No  Sun  Dinner     4
# 5        25.29  4.71    Male     No  Sun  Dinner     4
# 6         8.77  2.00    Male     No  Sun  Dinner     2
# 7        26.88  3.12    Male     No  Sun  Dinner     4
# 8        15.04  1.96    Male     No  Sun  Dinner     2
# 9        14.78  3.23    Male     No  Sun  Dinner     2
# 10       10.27  1.71    Male     No  Sun  Dinner     2
# 11       35.26  5.00  Female     No  Sun  Dinner     4
# 12       15.42  1.57    Male     No  Sun  Dinner     2
# 13       18.43  3.00    Male     No  Sun  Dinner     4
# 14       14.83  3.02  Female     No  Sun  Dinner     2
# 15       21.58  3.92    Male     No  Sun  Dinner     2
# ...

# %%
df17_3['day'].unique()
# Out:
# ['Sun', 'Sat', 'Thur', 'Fri']
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']

# %%
df17_3['h'] = df17_3['day'].apply(lambda x: 1 if x in ["Sat", "Sun"] else 2)

df17_3
# Out:
#      total_bill   tip     sex smoker   day    time  size  h
# 0         16.99  1.01  Female     No   Sun  Dinner     2  1
# 1         10.34  1.66    Male     No   Sun  Dinner     3  1
# 2         21.01  3.50    Male     No   Sun  Dinner     3  1
# 3         23.68  3.31    Male     No   Sun  Dinner     2  1
# 4         24.59  3.61  Female     No   Sun  Dinner     4  1
# ..          ...   ...     ...    ...   ...     ...   ... ..
# 239       29.03  5.92    Male     No   Sat  Dinner     3  1
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2  1
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2  1
# 242       17.82  1.75    Male     No   Sat  Dinner     2  1
# 243       18.78  3.00  Female     No  Thur  Dinner     2  2
#
# [244 rows x 8 columns]

# %%
sns.pairplot(df17_3, hue='h', diag_kind="hist", palette='bright');

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt 
import scipy
from scipy import stats
import random
import math 

# %matplotlib inline

# %%
def coint_flip():
    return random.randint(0, 1)

# list for add result
result_l = []

def monte_carlo(n):
    plt.subplots(figsize = (12,9))
    result = 0
    
    for i in range(n):
        flip_result = coint_flip()
        result = result +  flip_result
        
        prob_var = result / (i + 1)
        #print(prob_var)
        
        result_l.append(prob_var)
        
    plt.axhline(y = 0.5, color = 'r', linestyle = '-')
    plt.xlabel('Iterations')
    plt.ylabel('Probability')
    plt.plot(result_l)
    return result / n

# %%
answear = monte_carlo(50000)
print('Find value: ',answear)
# Out:
# Find value:  0.49748

# %%
doors = ['goat', 'goat', 'car']

switch_win_prob = []
stick_win_prob = []

plt.axhline(y = 0.6666, color = 'orange', linestyle = '-')
plt.axhline(y = 0.3333, color = 'blue', linestyle = '-')

def monte_carlo(n):
    
    switch_wins = 0
    stick_wins = 0
    
    for i in range(n):
        
        random.shuffle(doors)
        
        k = random.randrange(2)
        
        if doors[k] != 'car':
            switch_wins += 1
        else:
            stick_wins += 1
        
        switch_win_prob.append(switch_wins / (i + 1))
        stick_win_prob.append(stick_wins / (i + 1))
        
        plt.plot(switch_win_prob)
        plt.plot(stick_win_prob)
        
    print('Winning prob if you always switch: ',switch_win_prob[-1])
    print('Winning prob if you stay original choise: ',stick_win_prob[-1])
        
monte_carlo(500)
# Out:
# Winning prob if you always switch:  0.668
# Winning prob if you stay original choise:  0.332

# %% [markdown]
# > X1and X2are random variables of the results of rolling 2 fair dice.
# > Use a numpy simulation to show the distribution of the sum of the dice, i.e. X1+ X2.

# %%
x1 = np.random.randint(1, 7, size=10000)
x2 = np.random.randint(1, 7, size=10000)
x3 = np.random.randint(1, 7, size=10000)

# print(x1)
x4 = x1+x2+x3
sns.histplot(x4, bins=30)
# sns.boxplot(x3, palette='magma')
# print(x3)
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# ### Slide 18
# > X1, X2and X3are random variables of the results of rolling 3 fair dice.
# > Use a numpy simulation to show the distribution of:
#  1. P(X1+ X2+ X3)
#  2. P(X1+ X2+ X3| X3= 4)
#  3. P(X1+ X2+ X3| X1+ X2= 4)
#  4. Explain the results.

# %%
from sklearn.datasets import load_breast_cancer
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV, train_test_split



data = load_breast_cancer()

X_train, X_test, y_train, y_test = train_test_split(data.data, data.target, test_size=0.3, random_state=42)

parameters = {'n_estimators': [10, 20, 30, 50],
              'max_depth': [None, 5, 10, 20],
              'min_samples_split': [2, 5, 10],
              'min_samples_leaf': [1, 2, 4],
              'max_features': ['auto', 'sqrt', 'log2']}

rf = RandomForestClassifier()

grid_search = GridSearchCV(rf, parameters, cv=5, n_jobs=-1)
grid_search.fit(X_train, y_train)

print('Best parameters: ', grid_search.best_params_)
print('Best score: ', grid_search.best_score_)
# Out:
# /home/oleksandr/Documents/DAN_BI/Python/home_work_bi/.venv_bi/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /home/oleksandr/Documents/DAN_BI/Python/home_work_bi/.venv_bi/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# ...

# %%
column_names = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']
boston = pd.read_csv('./housing.csv', names = column_names, header=None, delimiter=r"\s+")

# %%
boston.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0  \
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2
